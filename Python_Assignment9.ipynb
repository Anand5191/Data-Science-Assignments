# %%
# Q1

"""In Python, we can define custom exceptions by creating a new class that is derived from the built-in Exception class.

The way this is processed is all the exceptions of the class MyCustomError and its subclasses (if any) will be caught.
This means if you specified our MyCustomError’s superclass which is the Exception class, this code will still work in the same manner.
When an exception occurs, the rest of the code inside the try block is skipped.

The except block catches the user-defined InvalidError exception and statements inside the except block are executed.
if our custom exception is about dealing with arithmetically related problems, it is best to use the ArithmeticError to inherit from.
if it’s about importing libraries we can inherit from ImportError or even its popular subclass ModuleNotFoundError.
If our problem is with the inputs given to a function or a method, then it’s best to inherit from ValueError
If our custom exception does not relate to any of these built-in exceptions, we can inherit directly from the Exception class itself."""

# %%
# Q2

import inspect

def treeClass(cls, ind = 0):

	print ('-' * ind, cls.__name__)

	for i in cls.__subclasses__():
		treeClass(i, ind + 3)

print("Hierarchy for Built-in exceptions is : ")

inspect.getclasstree(inspect.getmro(BaseException))

treeClass(BaseException)
# Out:
# Hierarchy for Built-in exceptions is :
#  BaseException
# --- Exception
# ------ TypeError
# --------- MultipartConversionError
# --------- FloatOperation
# --------- DTypePromotionError
# --------- UFuncTypeError
# ------------ UFuncTypeError
# --------------- UFuncTypeError
# ------------ UFuncTypeError
# --------------- UFuncTypeError
# --------------- UFuncTypeError
# --------- ConversionError
# ------ StopAsyncIteration
# ------ StopIteration
# ------ ImportError
# --------- ModuleNotFoundError
# ------------ PackageNotFoundError
# --------- ZipImportError
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# ------------ ConnectionAbortedError
# ------------ ConnectionRefusedError
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# --------- BlockingIOError
# --------- ChildProcessError
# --------- FileExistsError
# --------- FileNotFoundError
# ------------ ExecutableNotFoundError
# --------- IsADirectoryError
# ...

# %%
# Q3

# Ex: 1)
print (1/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-5-24dd75c7b6d4> in <cell line: 2>()
#       1 # Q3
# ----> 2 print (1/0)
#
# ZeroDivisionError: division by zero

# %%
# Ex: 2)

import math

print (math.exp(1000))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-10-070607b3a447> in <cell line: 5>()
#       3 import math
#       4
# ----> 5 print (math.exp(1000))
#       6
#
# OverflowError: math range error

# %%
#Q 4
array = { 'a':1, 'b':2 }
print (array['c'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-49601c9f2099> in <cell line: 4>()
#       2
#       3 array = { 'a':1, 'b':2 }
# ----> 4 print (array['c'])
#       5
#       6
#
# KeyError: 'c'

# %%
#Q 4
array = [ 0, 1, 2 ]
print (array[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-f2215b0cc6f2> in <cell line: 2>()
#       1 array = [ 0, 1, 2 ]
# ----> 2 print (array[3])
#
# IndexError: list index out of range

# %%
# Q5

"""“Python import errors” occur when the interpreter cannot locate a module or package required by a script or another module.
This can happen because of reasons such as issues with the Python path.

"""

#Ex :

import sys
try:
  from time import datetime
except Exception as e:
  print (e)
print (sys.exc_type)
# Out:
# cannot import name 'datetime' from 'time' (unknown location)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-5f4120fd6744> in <cell line: 15>()
#      13 except Exception as e:
#      14   print (e)
# ---> 15 print (sys.exc_type)
#
# AttributeError: module 'sys' has no attribute 'exc_type'

# %%
# Q5

""" “ModuleNotFoundError” This error occurs when you have not installed that module on your system and try to access the module
that the Python interpreter cannot locate in its search path or in the Python path."""

#Ex:

import pands as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-08a486f69d56> in <cell line: 6>()
#       4 that the Python interpreter cannot locate in its search path or in the Python path."""
#       5
# ----> 6 import pands as pd
#
# ModuleNotFoundError: No module named 'pands'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Q6

#Ex: 1)

try:
    numerator = 10
    denominator = 0

    result = numerator/denominator

    print(result)
except:
    print("Error: Denominator cannot be 0.")

# Output: Error: Denominator cannot be 0.
# Out:
# Error: Denominator cannot be 0.

# %%
# Q6

#Ex: 2)

try:
    result = 10 / 5
except ZeroDivisionError:
    print("Division by zero!")
else:
    print("Result is", result)
# Out:
# Result is 2.0

# %%
# Q6

#Ex: 3)

try:
    result = 10 / 0
except ZeroDivisionError:
    print("Division by zero!")
finally:
    print("This block of code will always execute.")
# Out:
# Division by zero!
# This block of code will always execute.
